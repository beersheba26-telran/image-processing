# %%
from ultralytics import YOLO
model = YOLO('yolov8m.pt')

# %%
results = model('street.jpg')
# Out:
# image 1/1 C:\Users\User\Documents\beersheba-26\back-end\image-processing\street.jpg: 640x512 5 persons, 1 bicycle, 2 cars, 1 backpack, 3 suitcases, 6837.3ms
# Speed: 22.7ms preprocess, 6837.3ms inference, 18.1ms postprocess per image at shape (1, 3, 640, 512)

# %%
img_annotated = results[0].plot()
import matplotlib.pyplot as plt
plt.imshow(img_annotated)
plt.show()
